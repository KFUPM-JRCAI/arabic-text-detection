# %%
# Import required libraries
import json
import jsonlines
import matplotlib.pyplot as plt
import seaborn as sns
from farasa.segmenter import FarasaSegmenter
from farasa.pos import FarasaPOSTagger
from farasa.ner import FarasaNamedEntityRecognizer
from tqdm.auto import tqdm
from collections import Counter

plt.rcParams['figure.figsize'] = (10, 6)
sns.set_style("whitegrid")

# %%
generated_by = 'allam'
generation_method = 'from_title'

# %%
# make sure the notebook is running from the project root
labeled_dataset_path = f'generated_arabic_datasets/{generated_by}/arabic_abstracts_dataset/from_title_abstracts_generation_filtered.jsonl'

# Load human-AI text pairs
human_texts = []
ai_texts = []
with jsonlines.open(labeled_dataset_path) as reader:
    for obj in reader:
        if 'original_abstract' in obj and 'generated_abstract' in obj:
            # Clean and validate text
            human_text = obj['original_abstract'].strip()
            ai_text = obj['generated_abstract'].strip()
            human_texts.append(human_text)
            ai_texts.append(ai_text)

len(human_texts), len(ai_texts)
# Out:
# (2963, 2963)

# %%
def get_text_annotation(annotator, text):
    # annotator should be a function: e.g tagger.tag
    annotated_text = annotator(text).strip('S/S').strip('E/E').strip()
    processed_annotated_text = ''
    for word in annotated_text.split():
        if '/' not in word:
            processed_annotated_text += word + '/UN_TAGGED '
        else:
            processed_annotated_text += f'{word} '
    processed_annotated_text = processed_annotated_text.strip()
    words_tags = []
    for annotated_word in processed_annotated_text.split():
        split_annotated_word = annotated_word.split('/')
        words_tags.append((split_annotated_word[0], split_annotated_word[1]))
    return words_tags

# %%
human_texts[0]
# Out:
# 'كثيرا ما ارتبطت المصادر التاريخية في الأندلس خاصة منها كتب التراجم والفهرسات والبرامج وغيرها بدراسة حياة العلماء والرواة والقضاة والساسة ؛ وقد تطورت هذه المادة حتى ترك لنا المؤلفون الأندلسيون سلسلة متواصلة الحلقات من كتب التـراجم كالصلة لابن بشكوال ، وصلة الصلة لابن الزبير، والتكملة لكتاب الصلة لابن الآبار، والذيل والتكملة لكتابي الموصول والصلة لابن عبد الملك المراكشي إضافة إلى الإحاطة في أخبار غرناطة لابن الخطيب ، إلا أنها لم تنس أن تشير في ثنايا أو بالأحرى في خواتم هذه المؤلفات إلى فئة المرأة العالمة التي ساهمت في الإنتاج الفكري والحضاري الأندلسي. ومن خلالها سنسعى إلى الوقوف على حالة التعليم عند المرأة الأندلسية ، وكيف كانت تأخذ فنون العلم. وما مدى إسهامها في الفكر التربوي والإنتاج الفكري الأندلسيين ؟.'

# %%
ai_texts[0]
# Out:
# 'يهدف هذا البحث إلى دراسة نظام التعليم عند المرأة الأندلسية خلال فترة الحكم الإسلامي في الأندلس (القرن الثامن إلى القرن الخامس عشر). من خلال تحليل المصادر التاريخية والأدبية، يسعى البحث إلى فهم دور المرأة في المجتمع الأندلسي ومدى تأثير التعليم على مكانتها ومشاركتها في الحياة العامة.\n\nيتبنى البحث منهجاً متعدد التخصصات، يجمع بين التاريخ والأدب وعلم الاجتماع. سيتم دراسة النصوص الأدبية والتاريخية التي تتناول موضوع التعليم والمرأة في الأندلس، بالإضافة إلى تحليل الآثار المادية والمواقع الأثرية التي تعكس الحياة اليومية للمرأة الأندلسية.\n\nمن المتوقع أن تسلط النتائج الضوء على أهمية التعليم في حياة المرأة الأندلسية وتأثيره على مكانتها الاجتماعية والثقافية. كما يتوقع أن يقدم البحث نظرة جديدة على دور المرأة في المجتمع الأندلسي ويساهم في فهم أعمق للتاريخ والثقافة الإسلامية في تلك الفترة.'

# %% [markdown]
# ## POS Tagging

# %%
annotated_human_texts = []
annotated_ai_texts = []

# %%
pos_tagger = FarasaPOSTagger(interactive=True)
# Out:
# [2025-09-02 10:50:16,190 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
pos_tagger.tag(human_texts[0])
# Out:
# 'S/S كثير/NOUN-MS +ا/CASE ما/PART ارتبط +ت/V+PRON ال+ مصادر/DET+NOUN-MS ال+ تاريخي +ة/DET+ADJ+NSUFF-FP في/PREP ال+ أندلس/DET+NOUN-MS خاص +ة/ADJ+NSUFF-FS من/PREP +ها/PRON كتب/NOUN-MS ال+ تراجم/DET+NOUN-MP و+/CONJ ال+ فهرس +ات/DET+NOUN+NSUFF-FD و+/CONJ ال+ برامج/DET+NOUN-MP و+/CONJ غير/PART +ها/PRON ب+/PREP دراس +ة/NOUN+NSUFF-FS حيا +ة/NOUN+NSUFF-FS ال+ علماء/DET+NOUN-MS و+/CONJ ال+ روا +ة/DET+NOUN+NSUFF-MP و+/CONJ ال+ قضا +ة/DET+NOUN+NSUFF-MP و+/CONJ ال+ ساس +ة/DET+NOUN+NSUFF-FP ؛/PUNC و+/CONJ قد/PART تطور +ت/V+PRON هذه/PRON ال+ ماد +ة/DET+NOUN+NSUFF-FS حتى/PREP ترك/NOUN-MS ل+/PREP +نا/PRON ال+ مؤلف +ون/DET+NOUN+NSUFF-MP ال+ أندلسي +ون/DET+ADJ+NSUFF-FD سلسل +ة/NOUN+NSUFF-FS متواصل +ة/ADJ+NSUFF-FP ال+ حلق +ات/DET+NOUN+NSUFF-FP من/PREP كتب/NOUN-MS ال+ تراجم/DET+NOUN-MP ك+/PREP ال+ صل +ة/DET+NOUN+NSUFF-FS ل+/PREP ابن/NOUN-MS بشكوال/NOUN-MS ،/PUNC وصل +ة/NOUN+NSUFF-FS ال+ صل +ة/DET+NOUN+NSUFF-FS ل+/PREP ابن/NOUN-MS ال+ زبير/DET+NOUN-MS ،/PUNC و+/CONJ ال+ تكمل +ة/DET+NOUN+NSUFF-FS ل+/PREP كتاب/NOUN-MS ال+ صل +ة/DET+NOUN+NSUFF-FS ل+/PREP ابن/NOUN-MS ال+ آبار/DET+NOUN-MP ،/PUNC و+/CONJ ال+ ذيل/DET+NOUN-MS و+/CONJ ال+ تكمل +ة/DET+NOUN+NSUFF-FS ل+/PREP كتابي/ADJ-MS ال+ موصول/DET+NOUN-MS و+/CONJ ال+ صل +ة/DET+NOUN+NSUFF-FS ل+/PREP ابن/NOUN-MS عبد/NOUN-MS ال+ ملك/DET+NOUN-MS ال+ مراكشي/DET+ADJ-MS إضاف +ة/NOUN+NSUFF-FS إلى/PREP ال+ إحاط +ة/DET+NOUN+NSUFF-FS في/PREP أخبار/NOUN-FP غرناط +ة/NOUN+NSUFF-FD ل+/PREP ابن/NOUN-MS ال+ خطيب/DET+NOUN-MS ،/PUNC إلا/PART أن/PART +ها/PRON لم/PART تنس/V أن/PART تشير/V في/PREP ثنايا/NOUN-FP أو/CONJ ب+/PREP ال+ أحرى/DET+NOUN-MS في/PREP خواتم/NOUN-FP هذه/PRON ال+ مؤلف +ات/DET+NOUN+NSUFF-FP إلى/PREP فئ +ة/NOUN+NSUFF-FS ال+ مرأ +ة/DET+NOUN+NSUFF-FS ال+ عالم +ة/DET+ADJ+NSUFF-FP التي/PART ساهم +ت/V+PRON في/PREP ال+ إنتاج/DET+NOUN-MS ال+ فكري/DET+ADJ-MS و+/CONJ ال+ حضاري/DET+ADJ-MS ال+ أندلسي/DET+ADJ-MS ./PUNC و+/CONJ +من/PART خلال/NOUN-MS +ها/PRON س+/FUT_PART نسعى/V إلى/PREP ال+ وقوف/DET+NOUN-MS على/PREP حال +ة/NOUN+NSUFF-FS ال+ تعليم/DET+NOUN-MS عند/NOUN-MS ال+ مرأ +ة/DET+NOUN+NSUFF-FS ال+ أندلسي +ة/DET+ADJ+NSUFF-FD ،/PUNC و+/CONJ كيف/PART كان +ت/V+PRON تأخذ/V فنون/NOUN-FP ال+ علم/DET+NOUN-MS ./PUNC و+/CONJ +ما/PART مدى/NOUN-MS إسهام/NOUN-MS +ها/PRON في/PREP ال+ فكر/DET+NOUN-MS ال+ تربوي/DET+ADJ-MS و+/CONJ ال+ إنتاج/DET+NOUN-MS ال+ فكري/DET+ADJ-MS ال+ أندلسي +ين/DET+ADJ+NSUFF-MP ؟/PUNC ./PUNC E/E'

# %%
for human_text, ai_text in tqdm(zip(human_texts, ai_texts),total=len(human_texts)):
    annotated_human_texts.extend(get_text_annotation(pos_tagger.tag, human_text))
    annotated_ai_texts.extend(get_text_annotation(pos_tagger.tag, ai_text))
# Out:
#   0%|          | 0/2963 [00:00<?, ?it/s]

# %%
human_pos_counts = Counter([tag for word, tag in annotated_human_texts])
ai_pos_counts = Counter([tag for word, tag in annotated_ai_texts])
human_pos_counts, ai_pos_counts
# Out:
# (Counter({'UN_TAGGED': 213866,
#           'NOUN-MS': 64905,
#           'PREP': 63873,
#           'DET+NOUN-MS': 44255,
#           'CONJ': 37272,
#           'PUNC': 37256,
#           'PRON': 35568,
#           'V': 25645,
#           'PART': 21103,
#           'DET+NOUN+NSUFF-FS': 18035,
#           'NOUN+NSUFF-FS': 17305,
#           'DET+ADJ-MS': 15485,
#           'DET+ADJ+NSUFF-FS': 9583,
#           'DET+NOUN+NSUFF-FP': 8682,
#           'NOUN-FP': 8492,
#           'DET+NOUN-MP': 7799,
#           'ADJ-MS': 7063,
#           'DET+ADJ+NSUFF-FD': 6660,
#           'CASE': 6535,
#           'V+PRON': 6219,
#           'NOUN+NSUFF-FP': 6123,
#           'DET+ADJ+NSUFF-FP': 4439,
#           'ADJ+NSUFF-FS': 3474,
#           'NOUN+NSUFF-FD': 3221,
#           'NUM-MP': 2160,
#           'ADJ+NSUFF-FP': 2002,
#           'NOUN-MP': 1899,
#           'DET+NOUN+NSUFF-MP': 1801,
#           'ADJ+NSUFF-FD': 1688,
#           'DET+ADJ+NSUFF-MP': 1435,
#           'PREP+PART': 1404,
#           'DET+NOUN+NSUFF-FD': 1361,
#           'ADV': 1089,
#           'NOUN-FS': 601,
#           'FOREIGN': 583,
#           'ABBREV': 541,
#           'ADJ+NSUFF-MP': 487,
#           'FUT_PART': 452,
#           'NOUN+NSUFF-MP': 444,
#           'NSUFF': 373,
#           'ADJ-FP': 230,
#           'DET+ADJ-MP': 200,
#           'NOUN+PART': 192,
#           'PART+PART': 144,
#           'ADJ-FS': 127,
#           '': 121,
#           'NUM-MS': 96,
#           'DET+NOUN-FP': 90,
#           'DET+NOUN+NSUFF+NSUFF-FD': 88,
#           'DET+NOUN+NSUFF-MD': 84,
#           'NOUN+NSUFF-MD': 78,
#           'ADJ-MP': 67,
#           'NOUN+NSUFF+NSUFF-FD': 56,
#           'NUM+NSUFF-FS': 53,
#           'NOUN+NSUFF-MS': 42,
#           'DET': 32,
#           'ADJ+NSUFF+NSUFF-FD': 27,
#           'DET+ADJ+NSUFF-MD': 26,
#           'V+PRON+PRON': 25,
#           'V+PART': 22,
#           '02': 17,
#           'DET+ADJ+NSUFF+NSUFF-FD': 16,
#           'DET+NOUN+NSUFF+NSUFF-FP': 14,
#           'NOUN+NSUFF+NSUFF-FP': 11,
#           '04': 9,
#           'ADJ+NSUFF-MD': 8,
#           '01': 8,
#           'NUM+NSUFF-MD': 7,
#           '05': 7,
#           'DET+NUM+NSUFF-FS': 6,
#           '03': 6,
#           '12': 6,
#           '07': 6,
#           'DET+NOUN+NSUFF+NSUFF-MP': 5,
#           'DET+NOUN+NSUFF+NSUFF-FS': 5,
#           '11': 5,
#           '10': 5,
#           'NOUN-MD': 5,
#           '16': 4,
#           '2019': 4,
#           'DET+PART': 4,
#           'DET+NOUN+NSUFF-MS': 4,
#           '247': 4,
#           'NOUN+NSUFF+NSUFF-FS': 3,
#           '3': 3,
#           'DET+NUM+NSUFF-MP': 3,
#           '1': 3,
#           '2018': 3,
#           '2017': 3,
#           '2016': 2,
#           'DET+NUM-MS': 2,
#           'NUM+NSUFF-MS': 2,
#           'DET+ADJ+NSUFF-MS': 2,
#           '09': 2,
#           '25': 2,
#           '06': 2,
#           '131': 2,
#           'DET+NUM-MP': 1,
#           '2014': 1,
#           '2003': 1,
#           '2007': 1,
#           'DET+NUM+NSUFF-MS': 1,
#           '86': 1,
#           '179': 1,
#           '54': 1,
#           '40': 1,
#           'ADJ+NSUFF+NSUFF-MP': 1,
#           '2': 1,
#           '13': 1,
#           'ADJ+NSUFF-MS': 1,
#           '74': 1,
#           '172': 1,
#           '493': 1,
#           '1995': 1,
#           '41': 1,
#           '8': 1,
#           '87': 1,
#           'DET+NUM+NSUFF-MD': 1,
#           '2020': 1}),
#  Counter({'UN_TAGGED': 160639,
#           'NOUN-MS': 45665,
#           'PREP': 40384,
#           'DET+NOUN-MS': 30827,
#           'CONJ': 19572,
#           'PUNC': 19544,
#           'V': 17341,
#           'DET+NOUN+NSUFF-FS': 16262,
#           'PRON': 13958,
#           'DET+ADJ-MS': 9710,
#           'NOUN+NSUFF-FS': 9249,
#           'DET+NOUN+NSUFF-FP': 8666,
#           'DET+ADJ+NSUFF-FS': 7619,
#           'DET+NOUN-MP': 6833,
#           'PART': 5668,
#           'DET+ADJ+NSUFF-FP': 5372,
#           'ADJ-MS': 5254,
#           'DET+ADJ+NSUFF-FD': 5166,
#           'NOUN+NSUFF-FP': 3936,
#           'CASE': 3565,
#           'NOUN-FP': 2923,
#           'FUT_PART': 1934,
#           'DET+NOUN+NSUFF-MP': 1840,
#           'DET+ADJ+NSUFF-MP': 1718,
#           'PREP+PART': 1335,
#           'E': 1178,
#           'S': 1178,
#           'ADJ+NSUFF-FS': 1051,
#           'NOUN+NSUFF-FD': 903,
#           'ADJ+NSUFF-FP': 854,
#           'ADJ+NSUFF-FD': 764,
#           'DET+NOUN+NSUFF-FD': 720,
#           'V+PRON': 713,
#           'NOUN-MP': 653,
#           'NUM-MP': 449,
#           'NOUN+NSUFF-MP': 373,
#           'NOUN-FS': 367,
#           'ADJ+NSUFF-MP': 241,
#           'NSUFF': 212,
#           'FOREIGN': 190,
#           'ADV': 154,
#           'DET+ADJ-MP': 132,
#           'ADJ-FS': 98,
#           'ABBREV': 70,
#           '': 50,
#           'NOUN+NSUFF+NSUFF-FD': 37,
#           'DET+NOUN+NSUFF-MD': 36,
#           'ADJ-FP': 35,
#           'DET+NOUN+NSUFF+NSUFF-FD': 25,
#           'DET+NOUN+NSUFF+NSUFF-FP': 15,
#           'DET+NOUN-FP': 12,
#           'NUM+NSUFF-FS': 8,
#           'ADJ-MP': 5,
#           'DET+NOUN+NSUFF+NSUFF-MP': 3,
#           'NOUN+NSUFF-MD': 3,
#           'ADJ+NSUFF+NSUFF-FD': 3,
#           'DET+ADJ+NSUFF-MD': 3,
#           'NUM-MS': 3,
#           'DET+NUM+NSUFF-MP': 2,
#           'NOUN+PART': 2,
#           '07': 2,
#           'DET+NOUN+NSUFF+NSUFF-FS': 1,
#           'DET+ADJ+NSUFF+NSUFF-FD': 1,
#           'NUM+NSUFF-MS': 1,
#           'NOUN+NSUFF-MS': 1,
#           '21': 1,
#           '15': 1,
#           'DET+NUM-MS': 1,
#           'V+PRON+PRON': 1,
#           'DET+NUM+NSUFF-FS': 1,
#           'DET': 1,
#           '13': 1,
#           '04': 1,
#           '17': 1,
#           '16': 1,
#           '09': 1,
#           '957': 1}))

# %%
# save counters as json files
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/human_pos_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        human_pos_counts, 
        f,
        ensure_ascii=False,
        indent=4,
    )
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/ai_pos_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        ai_pos_counts,
        f,
        ensure_ascii=False,
        indent=4,
    )

# %% [markdown]
# ## NER

# %%
annotated_human_texts = []
annotated_ai_texts = []

# %%
ner_tagger = FarasaNamedEntityRecognizer(interactive=True)
# Out:
# [2025-09-02 10:53:28,569 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
ner_tagger.recognize(human_texts[0])
# Out:
# 'كثيرا/O ما/O ارتبطت/O المصادر/O التاريخية/O في/O الأندلس/B-LOC خاصة/O منها/O كتب/O التراجم/O والفهرسات/O والبرامج/O وغيرها/O بدراسة/O حياة/O العلماء/O والرواة/O والقضاة/O والساسة/O ؛/O وقد/O تطورت/O هذه/O المادة/O حتى/O ترك/O لنا/O المؤلفون/O الأندلسيون/O سلسلة/O متواصلة/O الحلقات/O من/O كتب/O التراجم/O كالصلة/O لابن/B-PERS بشكوال/I-PERS ،/O وصلة/O الصلة/O لابن/B-PERS الزبير/I-PERS ،/O والتكملة/O لكتاب/O الصلة/O لابن/B-PERS الآبار/I-PERS ،/O والذيل/O والتكملة/O لكتابي/O الموصول/O والصلة/O لابن/O عبد/B-PERS الملك/I-PERS المراكشي/I-PERS إضافة/O إلى/O الإحاطة/O في/O أخبار/O غرناطة/B-LOC لابن/B-PERS الخطيب/I-PERS ،/O إلا/O أنها/O لم/O تنس/O أن/O تشير/O في/O ثنايا/O أو/O بالأحرى/O في/O خواتم/O هذه/O المؤلفات/O إلى/O فئة/O المرأة/O العالمة/O التي/O ساهمت/O في/O الإنتاج/O الفكري/O والحضاري/O الأندلسي/O ./O ومن/O خلالها/O سنسعى/O إلى/O الوقوف/O على/O حالة/O التعليم/O عند/O المرأة/O الأندلسية/O ،/O وكيف/O كانت/O تأخذ/O فنون/O العلم/O ./O وما/O مدى/O إسهامها/O في/O الفكر/O التربوي/O والإنتاج/O الفكري/O الأندلسيين/O ؟/O ./O'

# %%
for i,(human_text, ai_text) in tqdm(enumerate(zip(human_texts, ai_texts)),total=len(human_texts)):
    annotated_human_texts.extend(get_text_annotation(ner_tagger.recognize, human_text))
    annotated_ai_texts.extend(get_text_annotation(ner_tagger.recognize, ai_text))
    if 2300 > i > 2400 and i % 50 == 0: # I needed to do that as the tagger becomes stale after some time! (in this case, it stales at the index 2354)
        ner_tagger = FarasaNamedEntityRecognizer(interactive=True)
# Out:
#   0%|          | 0/2963 [00:00<?, ?it/s]
# [2025-09-02 10:54:08,112 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:54:44,676 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:55:22,621 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:55:58,085 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:56:33,052 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:57:09,030 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:57:45,109 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:58:23,388 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:59:00,618 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 10:59:38,575 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:00:16,851 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:00:54,014 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:01:30,549 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:02:08,587 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:02:44,461 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:03:20,355 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:03:55,513 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:04:35,098 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:05:13,847 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:05:52,642 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:06:30,949 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:07:09,306 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:07:44,153 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:08:25,538 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:09:02,055 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:09:38,954 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:10:15,546 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:10:51,398 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:11:27,161 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:12:03,768 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:12:40,676 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:13:16,365 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:13:51,117 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:14:27,961 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:15:06,194 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:15:42,898 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:16:21,270 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:16:57,452 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:17:34,255 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:18:10,709 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:18:47,798 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:19:22,113 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:20:00,177 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:20:38,353 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:21:17,198 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:21:47,909 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:22:24,611 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:23:02,906 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:23:42,400 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:24:21,607 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:24:58,428 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:25:34,051 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:26:10,811 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:26:46,041 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:27:22,063 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:27:58,093 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:28:36,052 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:29:12,798 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# [2025-09-02 11:29:46,748 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
human_ner_counts = Counter([tag for word, tag in annotated_human_texts])
ai_ner_counts = Counter([tag for word, tag in annotated_ai_texts])
human_ner_counts, ai_ner_counts
# Out:
# (Counter({'O': 383965,
#           'B-LOC': 2297,
#           'I-PERS': 1711,
#           'B-PERS': 1420,
#           'B-ORG': 414,
#           'I-ORG': 408,
#           'I-LOC': 259,
#           '': 119,
#           'UN_TAGGED': 29,
#           '02': 17,
#           '04': 9,
#           '01': 8,
#           '05': 7,
#           '03': 6,
#           '12': 6,
#           '07': 6,
#           '11': 5,
#           '10': 5,
#           '16': 4,
#           '2019': 4,
#           '247': 4,
#           '3': 3,
#           '1': 3,
#           '2018': 3,
#           '2017': 3,
#           '2016': 2,
#           '09': 2,
#           '25': 2,
#           '06': 2,
#           '131': 2,
#           '2014': 1,
#           '2003': 1,
#           '2007': 1,
#           '86': 1,
#           '179': 1,
#           '54': 1,
#           '40': 1,
#           '2': 1,
#           '13': 1,
#           '74': 1,
#           '172': 1,
#           '493': 1,
#           '1995': 1,
#           '41': 1,
#           '8': 1,
#           '87': 1,
#           '2020': 1}),
#  Counter({'O': 243059,
#           'B-LOC': 1552,
#           'I-PERS': 1005,
#           'B-PERS': 868,
#           'I-ORG': 257,
#           'B-ORG': 219,
#           'I-LOC': 154,
#           '': 49,
#           'UN_TAGGED': 46,
#           '07': 2,
#           '21': 1,
#           '15': 1,
#           '13': 1,
#           '04': 1,
#           '17': 1,
#           '16': 1,
#           '09': 1,
#           '957': 1}))

# %%
# save counters as json files
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/human_ner_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        human_ner_counts, 
        f,
        ensure_ascii=False,
        indent=4,
    )
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/ai_ner_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        ai_ner_counts,
        f,
        ensure_ascii=False,
        indent=4,
    )

# %% [markdown]
# ## Segmentation

# %%
annotated_human_texts = []
annotated_ai_texts = []

# %%
segmenter = FarasaSegmenter(interactive=True)
# Out:
# [2025-09-02 11:30:05,666 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
segmenter.segment(human_texts[0])
# Out:
# 'كثير+ا ما ارتبط+ت ال+مصادر ال+تاريخي+ة في ال+أندلس خاص+ة من+ها كتب ال+تراجم و+ال+فهرس+ات و+ال+برامج و+غير+ها ب+دراس+ة حيا+ة ال+علماء و+ال+روا+ة و+ال+قضا+ة و+ال+ساس+ة ؛ و+قد تطور+ت هذه ال+ماد+ة حتى ترك ل+نا ال+مؤلف+ون ال+أندلسي+ون سلسل+ة متواصل+ة ال+حلق+ات من كتب ال+تراجم ك+ال+صل+ة ل+ابن بشكوال ، وصل+ة ال+صل+ة ل+ابن ال+زبير ، و+ال+تكمل+ة ل+كتاب ال+صل+ة ل+ابن ال+آبار ، و+ال+ذيل و+ال+تكمل+ة ل+كتابي ال+موصول و+ال+صل+ة ل+ابن عبد ال+ملك ال+مراكشي إضاف+ة إلى ال+إحاط+ة في أخبار غرناط+ة ل+ابن ال+خطيب ، إلا أن+ها لم تنس أن تشير في ثنايا أو ب+ال+أحرى في خواتم هذه ال+مؤلف+ات إلى فئ+ة ال+مرأ+ة ال+عالم+ة التي ساهم+ت في ال+إنتاج ال+فكري و+ال+حضاري ال+أندلسي . و+من خلال+ها س+نسعى إلى ال+وقوف على حال+ة ال+تعليم عند ال+مرأ+ة ال+أندلسي+ة ، و+كيف كان+ت تأخذ فنون ال+علم . و+ما مدى إسهام+ها في ال+فكر ال+تربوي و+ال+إنتاج ال+فكري ال+أندلسي+ين ؟ .'

# %%
def process_segmentations(annotated_text):
    all_subtokens = list()
    for token in annotated_text.split():
        subtokens = token.split('+')
        subtokens = [subtoken.strip() for subtoken in subtokens]  # noqa: E731
        all_subtokens.extend(subtokens)
    return all_subtokens

# %%
human_segmentations = []
ai_segmentations = []

# %%
for human_text, ai_text in tqdm(zip(human_texts, ai_texts),total=len(human_texts)):
    human_segmentations.extend(process_segmentations(segmenter.segment(human_text)))
    ai_segmentations.extend(process_segmentations(segmenter.segment(ai_text)))
# Out:
#   0%|          | 0/2963 [00:00<?, ?it/s]

# %%
human_segmentations[:10], ai_segmentations[:10]
# Out:
# (['كثير', 'ا', 'ما', 'ارتبط', 'ت', 'ال', 'مصادر', 'ال', 'تاريخي', 'ة'],
#  ['يهدف', 'هذا', 'ال', 'بحث', 'إلى', 'دراس', 'ة', 'نظام', 'ال', 'تعليم'])

# %%
human_segmentations_counts = Counter(human_segmentations)
ai_segmentations_counts = Counter(ai_segmentations)
human_segmentations_counts.most_common(5), ai_segmentations_counts.most_common(5)
# Out:
# ([('ال', 120165), ('ة', 67760), ('و', 33219), ('،', 20242), ('ات', 13694)],
#  [('ال', 94968), ('ة', 49142), ('و', 19511), ('ات', 12802), ('.', 12363)])

# %%
# save counters as json files
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/human_segmentations_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        human_segmentations_counts, 
        f,
        ensure_ascii=False,
        indent=4,
    )
with open(f'notebooks/stylometric_analysis/abstracts_dataset/{generated_by}/{generation_method}/ai_segmentations_counts.json', 'w', encoding='utf-8') as f:
    json.dump(
        ai_segmentations_counts,
        f,
        ensure_ascii=False,
        indent=4,
    )
