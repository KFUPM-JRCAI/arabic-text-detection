# %% [markdown]
# # Stylometric Analysis: Human vs AI Generated Arabic Text
#
# This notebook performs comprehensive stylometric analysis of Arabic text to identify differences between human-written and AI-generated content using:
#
# 1. **Part-of-Speech (POS) Tagging** - Analyzing grammatical patterns
# 2. **Named Entity Recognition (NER)** - Examining entity usage patterns
# 3. **Morphological Segmentation** - Understanding word structure complexity
#
# **Dataset**: Labeled human vs AI Arabic social media posts
# **Tools**: farasapy Arabic NLP toolkit
# **Goal**: Identify linguistic markers for AI text detection

# %%
# Import required libraries
import jsonlines
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from farasa.segmenter import FarasaSegmenter
from farasa.pos import FarasaPOSTagger
from farasa.ner import FarasaNamedEntityRecognizer
from tqdm.auto import tqdm
from collections import Counter

warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (10, 6)
sns.set_style("whitegrid")

# %%
# make sure the notebook is running from the project root
labeled_dataset_path = 'generated_arabic_datasets/jais-batched/arabic_social_media_dataset/by_polishing_posts_generation_filtered.jsonl'

# Load human-AI text pairs
human_texts = []
ai_texts = []
with jsonlines.open(labeled_dataset_path) as reader:
    for obj in reader:
        if 'original_post' in obj and 'generated_post' in obj:
            # Clean and validate text
            human_text = obj['original_post'].strip()
            ai_text = obj['generated_post'].strip()
            human_texts.append(human_text)
            ai_texts.append(ai_text)

len(human_texts), len(ai_texts)
# Out:
# (3318, 3318)

# %%
def get_text_annotation(annotator, text):
    # annotator should be a function: e.g tagger.tag
    annotated_text = annotator(text).strip('S/S').strip('E/E').strip()
    processed_annotated_text = ''
    for word in annotated_text.split():
        if '/' not in word:
            processed_annotated_text += word + '/UN_TAGGED '
        else:
            processed_annotated_text += f'{word} '
    processed_annotated_text = processed_annotated_text.strip()
    words_tags = []
    for annotated_word in processed_annotated_text.split():
        split_annotated_word = annotated_word.split('/')
        words_tags.append((split_annotated_word[0], split_annotated_word[1]))
    return words_tags

# %%
human_texts[0]
# Out:
# "هنا الكثير من منيف، والكثير من شرق المتوسط أيضا. الأم هنا متعب الهذال في مدن الملح، أما أنيسة ورجب وحامد فهم الإنسان بكل تقلباته. لم أحب شخصية أنيسة، أزعجتني حقيقة. الرواية على أنها رائعة، وعلى أنها ذكرتني بالأشجار واغتيال مرزوق وجوها العام، إلا أنني توقعتها بشكل مختلف. توقعت السجون أرذل وأقذر وأقسى على الإنسان من هذا، ولا أقصد الأوصاف الحسية هنا. لعلي أرى ماتوقعت في 'الآن هنا..'. شرق المتوسط- عبدالرحمن منيف ???. سوف تنام طويلا، الموت والنوم متشابهان. لا فرق بينهما إلا ان الأول طويل والآخر قصير، ألا تنهض لنعيش فترة أطول؟ ص??. السجن والمرأة لا يجتمعان، وبداية انهيار السجين ان يسيطر عليه شبح امرأة. كفوا عن هذا المرض أيها الثيران، اخصوا أنفسكم لينتهي عذابكم! ص??. ... وانا من الذي ينتظرني؟ ص??. ... وفي تلك الدقائق، التي لم تكن تزيد على العشر أتزود بالقوة، بالجنون، بالمحبة، كنت أتزود منها لفترة طويلة تكفيني أسابيع، حتى عندما يمنعون الزيارة. ص??. وصمتت تاركة لدمعة كبيرة ان تسقط دون ان توقفها او تمسحها كما تعودت ان تفعل. ولما سألتها مر
ما يخرج رجب من السجن سيكون كبيرا شامخا مثلها!. ولأول مرة رأيت وجه رجب يتقلص من الألم، ثم تركني بسرعة. ارتكى على حائط الدار باستسلام يائس، وبعد لحظة صمت مدمرة بكى. كان بكاء متوجعا, أقرب إلى النشيج.. ص??. - اذا كانت كل أم تقول الكلمات التي تقولينها فلن يتحرك أحد، وسوف نموت في المزابل. ص???. السجن يعود! والسيجارة الأولى الآن تجعل"

# %% [markdown]
# ## POS tagging

# %%
# Initialize Farasa NLP tools
pos_tagger = FarasaPOSTagger(interactive=True)
# Out:
# [2025-09-01 09:36:49,624 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
pos_tagger.tag(human_texts[0])
# Out:
# "S/S هنا/ADV ال+ كثير/DET+NOUN-MS من/PREP منيف/NOUN-MS ،/PUNC و+/CONJ ال+ كثير/DET+NOUN-MS من/PREP شرق/NOUN-MS ال+ متوسط/DET+NOUN-MS أيض/ADV +ا/CASE ./PUNC ال+ أم/DET+NOUN-MS هنا/NOUN-MS متعب/NOUN-MS ال+ هذال/DET+NOUN-MS في/PREP مدن/NOUN-FP ال+ ملح/DET+NOUN-MS ،/PUNC أما/PART أنيس +ة/NOUN+NSUFF-FD و+/CONJ رجب/NOUN-MS و+/CONJ حامد/NOUN-MS فهم/NOUN-MS ال+ إنسان/DET+NOUN-MS ب+/PREP كل/NOUN-MS تقلب +ات/NOUN+NSUFF-FP +ه/PRON ./PUNC لم/PART أحب/V شخصي +ة/NOUN+NSUFF-FS أنيس +ة/ADJ+NSUFF-FD ،/PUNC أزعجتني/NOUN-MS حقيق +ة/NOUN+NSUFF-FS ./PUNC ال+ رواي +ة/DET+NOUN+NSUFF-FS على/PREP أن/PART +ها/PRON رائع +ة/ADJ+NSUFF-FP ،/PUNC و+/CONJ على/PREP أن/PART +ها/PRON ذكرتني/NOUN-MS ب+/PREP ال+ أشجار/DET+NOUN-MP و+/CONJ اغتيال/NOUN-MS مرزوق/NOUN-MS و+/CONJ جو/NOUN-MS +ها/PRON ال+ عام/DET+ADJ-MS ،/PUNC إلا/PART أنني/V توقع +ت/V+PRON +ها/PRON ب+/PREP شكل/NOUN-MS مختلف/ADJ-MS ./PUNC توقع +ت/V+PRON ال+ سجون/DET+NOUN-MP أرذل/V و+/CONJ أقذر/NOUN-FP و+/CONJ أقسى/NOUN-MS على/PREP ال+ إنسان/DET+NOUN-MS من/PREP هذا/PRON ،/PUNC و+/CONJ لا/PART أقصد/V ال+ أوصاف/DET+NOUN-MP ال+ حسي +ة/DET+ADJ+NSUFF-FS هنا/ADV ./PUNC ل+/PREP علي/NOUN-MS أرى/V ماتوقعت/NOUN-MS في/PREP '/PUNC الآن/ADV هنا/ADV ./PUNC ./PUNC '/PUNC ./PUNC شرق/NOUN-MS ال+ متوسط/DET+NOUN-MS -/PUNC عبدالرحمن/NOUN-MS منيف/NOUN-MS ?/PUNC ?/PUNC ?/PUNC ./PUNC سوف/FUT_PART تنام/V طويل/ADJ-MS +ا/CASE ،/PUNC ال+ موت/DET+NOUN-MS و+/CONJ ال+ نوم/DET+NOUN-MS متشابه +ان/ADJ+NSUFF-FD ./PUNC لا/PART فرق/NOUN-MS بين/NOUN-MS +هما/PRON إلا/PART ان/NOUN-MS ال+ أول/DET+ADJ-MS طويل/ADJ-MS و+/CONJ ال+ آخر/DET+NOUN-MS قصير/ADJ-MS ،/PUNC ألا/PART+PART تنهض/V ل+/PREP نعيش/V فتر +ة/NOUN+NSUFF-FS أطول/ADJ-MS ؟/PUNC ص/ABBREV ?/PUNC ?/PUNC ./PUNC ال+ سجن/DET+NOUN-MS و+/CONJ ال+ مرأ +ة/DET+NOUN+NSUFF-FS لا/PART يجتمعان/NOUN-MS ،/PUNC و+/CONJ بداي +ة/NOUN+NSUFF-FS انهيار/NOUN-MS ال+ سجين/DET+NOUN-MS ان/NOUN-MS يسيطر/V علي/PREP +ه/PRON شبح/NOUN-MS امرأ +ة/NOUN+NSUFF-FS ./PUNC كف +وا/V+PRON عن/PREP هذا/PRON ال+ مرض/DET+NOUN-MS أيها/PART ال+ ثيران/DET+NOUN-MP ،/PUNC اخص +وا/V+PRON أنفس/NOUN-FP +كم/PRON ل+/PREP ينتهي/V عذاب/NOUN-MS +كم/PRON !/PUNC ص/ABBREV ?/PUNC ?/PUNC ./PUNC ./PUNC ../PUNC و+/CONJ أنا/PRON من/PREP الذي/PART ينتظرني/NOUN-MS ؟/PUNC ص/ABBREV ?/PUNC ?/PUNC ./PUNC ./PUNC ../PUNC و+/CONJ في/PREP تلك/PRON ال+ دقائق/DET+NOUN-MP ،/PUNC التي/PART لم/PART تكن/V تزيد/V على/PREP ال+ عشر/DET+ADJ-MS أتزود/NOUN-MS ب+/PREP ال+ قو +ة/DET+NOUN+NSUFF-FS ،/PUNC ب+/PREP ال+ جنون/DET+NOUN-MS ،/PUNC ب+/PREP ال+ محب +ة/DET+NOUN+NSUFF-FS ،/PUNC كن +ت/V+PRON أتزود/NOUN-MS من/PREP +ها/PRON ل+/PREP فتر +ة/NOUN+NSUFF-FS طويل +ة/ADJ+NSUFF-FP تكفيني/NOUN-MS أسابيع/NOUN-FP ،/PUNC حتى/ADV عندما/NOUN+PART يمنع +ون/V+PRON ال+ زيار +ة/DET+NOUN+NSUFF-FS ./PUNC ص/ABBREV ?/PUNC ?/PUNC ./PUNC و+/CONJ صمت +ت/V+PRON تارك +ة/NOUN+NSUFF-FD ل+/PREP دمع +ة/NOUN+NSUFF-FS كبير +ة/ADJ+NSUFF-FS ان/NOUN-MS تسقط/V دون/NOUN-MS ان/NOUN-MS توقف/V +ها/PRON أو/CONJ تمسح/V +ها/PRON كما/PREP+PART تعود +ت/V+PRON ان/NOUN-MS تفعل/V ./PUNC و+/CONJ لما/PREP+PART سأل +ت/V+PRON +ها/PRON مر +ة/NOUN+NSUFF-FS أخرى/ADJ-MS ،/PUNC جاء +ت/V+PRON ك+/PREP لما +ت/NOUN+NSUFF-FP +ها/PRON غامض +ة/ADJ+NSUFF-FD حزين +ة/ADJ+NSUFF-FD :/PUNC ./PUNC -/PUNC ال+ كلب/DET+NOUN-MS أمسكني/NOUN-MS من/PREP صدري/NOUN-MS ./PUNC ./PUNC و+/CONJ أشار +ت/V+PRON ب+/PREP رأس/NOUN-MS +ها/PRON إلى/PREP ال+ حارس/DET+NOUN-MS الذي/PART كان/V يدور/V حول/NOUN-MS +نا/PRON ./PUNC ص/ABBREV ?/PUNC ?/PUNC ./PUNC -/PUNC الله/NOUN-MS يقطع/V هذي/PRON ال+ أم/DET+NOUN-MS ،/PUNC هذه/PRON ليس +ت/V+PRON أما/PART ،/PUNC هذه/PRON مزبل +ة/ADJ+NSUFF-FS ،/PUNC نكون/V جالس +ين/ADJ+NSUFF-MP ب+/PREP انتظار/NOUN-MP ان/NOUN-MS يسمح +وا/V+PRON ل+/PREP +نا/PRON أو/CONJ ان/NOUN-MS يأخذ +وا/V+PRON ال+ أكل/DET+NOUN-MS ،/PUNC و+/CONJ +ما/PART ان/NOUN-MS يظهر/V آمر/NOUN-MS ال+ حرس/DET+NOUN-MS ،/PUNC و+/CONJ يبدأ/V ينادي/V على/PREP ال+ أسماء/DET+NOUN-MP ،/PUNC حتى/PART تولول/V و+/CONJ ال+ دموع/DET+NOUN-MS على/PREP خدي/NOUN-MS +ها/PRON قناطير/NOUN-MP ./PUNC قبل/NOUN-MS دقيق +ة/NOUN+NSUFF-FS كان +ت/V+PRON امرأ +ة/NOUN+NSUFF-FS عاقل +ة/ADJ+NSUFF-FS ،/PU ...

# %%
annotated_human_texts = []
annotated_ai_texts = []

# %%
for human_text, ai_text in tqdm(zip(human_texts, ai_texts),total=len(human_texts)):
    annotated_human_texts.extend(get_text_annotation(pos_tagger.tag, human_text))
    annotated_ai_texts.extend(get_text_annotation(pos_tagger.tag, ai_text))
# Out:
#   0%|          | 0/3318 [00:00<?, ?it/s]

# %%
human_tag_counts = Counter([tag for word, tag in annotated_human_texts])
ai_tag_counts = Counter([tag for word, tag in annotated_ai_texts])
human_tag_counts, ai_tag_counts
# Out:
# (Counter({'UN_TAGGED': 1091235,
#           'NOUN-MS': 631838,
#           'PUNC': 489697,
#           'PREP': 456733,
#           'PRON': 398042,
#           'V': 324118,
#           'DET+NOUN-MS': 305911,
#           'CONJ': 287660,
#           'PART': 263363,
#           'NOUN+NSUFF-FS': 102776,
#           'DET+NOUN+NSUFF-FS': 92946,
#           'ADJ-MS': 88188,
#           'CASE': 75158,
#           'V+PRON': 72599,
#           'NOUN-FP': 57409,
#           'DET+ADJ-MS': 57039,
#           'DET+NOUN-MP': 38093,
#           'NOUN+NSUFF-FD': 37126,
#           'NUM-MP': 33582,
#           'NOUN+NSUFF-FP': 33420,
#           'DET+NOUN+NSUFF-FP': 25978,
#           'DET+ADJ+NSUFF-FS': 22063,
#           'ADV': 21463,
#           'FOREIGN': 18563,
#           'ADJ+NSUFF-FS': 18197,
#           'NOUN-MP': 17196,
#           'ADJ+NSUFF-FP': 14727,
#           'DET+ADJ+NSUFF-FD': 13745,
#           'DET+ADJ+NSUFF-FP': 13348,
#           'ADJ+NSUFF-FD': 11895,
#           'DET+NOUN+NSUFF-MP': 10880,
#           'PREP+PART': 8937,
#           'DET+NOUN+NSUFF-FD': 8135,
#           'FUT_PART': 7445,
#           'NOUN+PART': 7426,
#           'ABBREV': 5203,
#           'NOUN+NSUFF-MP': 5021,
#           'NOUN-FS': 4746,
#           'DET+ADJ+NSUFF-MP': 3948,
#           'NSUFF': 3164,
#           'PART+PART': 2725,
#           'ADJ+NSUFF-MP': 2600,
#           'ADJ-FP': 2030,
#           '': 1925,
#           'ADJ-FS': 1309,
#           'DET+ADJ-MP': 1298,
#           'NUM-MS': 1272,
#           'ADJ-MP': 1052,
#           'NOUN+NSUFF-MD': 906,
#           'DET': 800,
#           'NUM+NSUFF-FS': 784,
#           'NOUN+NSUFF+NSUFF-FD': 522,
#           'V+PART': 359,
#           'DET+NOUN-FP': 359,
#           'DET+NOUN+NSUFF+NSUFF-FD': 357,
#           'NOUN+NSUFF-MS': 306,
#           'NOUN-MD': 286,
#           'NOUN+NSUFF+NSUFF-FP': 226,
#           'DET+NOUN+NSUFF-MD': 209,
#           'NUM+NSUFF-MD': 199,
#           'V+PRON+PRON': 189,
#           'ADJ+NSUFF+NSUFF-FD': 189,
#           'DET+ADJ+NSUFF+NSUFF-FD': 153,
#           'ADJ+NSUFF-MD': 122,
#           'NUM+NSUFF-MP': 113,
#           'DET+NOUN+NSUFF+NSUFF-FP': 113,
#           'NUM+NSUFF-MS': 108,
#           'DET+ADJ+NSUFF-MD': 95,
#           'DET+NUM+NSUFF-FS': 66,
#           '10': 57,
#           'DET+NOUN+NSUFF-MS': 48,
#           '5': 43,
#           'DET+NUM+NSUFF-MD': 40,
#           'DET+NUM+NSUFF-MP': 38,
#           '.': 37,
#           'NOUN+NSUFF+NSUFF-FS': 35,
#           'NOUN+NSUFF+NSUFF-MP': 28,
#           'NUM+NSUFF-FP': 26,
#           'NUM+NSUFF+NSUFF-MD': 25,
#           'DET+NUM-MS': 23,
#           'DET+NOUN+NSUFF+NSUFF-FS': 20,
#           'DET+NOUN+NSUFF+NSUFF-MP': 15,
#           'DET+NUM+NSUFF-MS': 11,
#           'DET+ADJ+NSUFF-MS': 11,
#           'NOUN+NSUFF+NSUFF-MD': 10,
#           'DET+NUM+NSUFF-FP': 10,
#           'NUM-MD': 9,
#           '2': 8,
#           'ADJ+NSUFF-MS': 8,
#           'DET+NUM-MP': 7,
#           '4': 7,
#           '3': 6,
#           '7': 5,
#           '0': 5,
#           '6': 4,
#           '1': 4,
#           '04': 3,
#           '01': 3,
#           'NUM-FP': 3,
#           '12': 3,
#           '06': 3,
#           '90': 3,
#           '02': 2,
#           '08': 2,
#           '05': 2,
#           'DET+ADJ-FP': 2,
#           'NUM+NSUFF-FD': 2,
#           'DET+PART': 1,
#           '553': 1,
#           '265': 1,
#           '186': 1,
#           '142': 1,
#           '228': 1,
#           '23': 1,
#           '11': 1,
#           '4552': 1,
#           '26': 1,
#           'DET+ADJ+NSUFF+NSUFF-FS': 1,
#           '72129': 1,
#           '03': 1,
#           '09': 1,
#           '170': 1,
#           '2003': 1,
#           '24': 1,
#           '72': 1,
#           'NOUN-FD': 1,
#           '54': 1,
#           '230': 1,
#           '185': 1,
#           '951': 1,
#           '231': 1,
#           '80645': 1,
#           '20': 1}),
#  Counter({'UN_TAGGED': 445226,
#           'NOUN-MS': 194988,
#           'PUNC': 183381,
#           'PREP': 169837,
#           'PRON': 127817,
#           'V': 119649,
#           'DET+NOUN-MS': 119525,
#           'PART': 98354,
#           'CONJ': 89645,
#           'DET+NOUN+NSUFF-FS': 42364,
#           'NOUN+NSUFF-FS': 40660,
#           'ADJ-MS': 30728,
#           'V+PRON': 28476,
#           'CASE': 25236,
#           'DET+ADJ-MS': 21352,
#           'NOUN-FP': 19322,
#           'DET+NOUN-MP': 17005,
#           'E': 16399,
#           'S': 16399,
#           'NOUN+NSUFF-FP': 12225,
#           'NOUN+NSUFF-FD': 11652,
#           'DET+NOUN+NSUFF-FP': 11281,
#           'DET+ADJ+NSUFF-FS': 10343,
#           'ADV': 8235,
#           'ADJ+NSUFF-FS': 7900,
#           'ADJ+NSUFF-FP': 7205,
#           'NUM-MP': 6293,
#           'DET+ADJ+NSUFF-FP': 6268,
#           'DET+ADJ+NSUFF-FD': 5226,
#           'ADJ+NSUFF-FD': 4951,
#           'DET+NOUN+NSUFF-MP': 4792,
#           'NOUN-MP': 4179,
#           'PREP+PART': 4045,
#           'NOUN+PART': 3498,
#           'FUT_PART': 2589,
#           'DET+NOUN+NSUFF-FD': 1940,
#           'DET+ADJ+NSUFF-MP': 1686,
#           'NOUN+NSUFF-MP': 1639,
#           'NOUN-FS': 1509,
#           'FOREIGN': 1455,
#           'ADJ+NSUFF-MP': 1149,
#           'NSUFF': 1021,
#           'ABBREV': 763,
#           'ADJ-FP': 613,
#           'NUM-MS': 505,
#           'DET+ADJ-MP': 432,
#           'PART+PART': 427,
#           'NOUN+NSUFF-MD': 406,
#           'NUM+NSUFF-FS': 404,
#           'ADJ-FS': 386,
#           '': 378,
#           'NOUN+NSUFF+NSUFF-FD': 249,
#           'ADJ-MP': 198,
#           'DET+NOUN-FP': 167,
#           'DET': 152,
#           'DET+NOUN+NSUFF+NSUFF-FD': 114,
#           'NOUN+NSUFF+NSUFF-FP': 106,
#           'ADJ+NSUFF+NSUFF-FD': 101,
#           'V+PART': 91,
#           'V+PRON+PRON': 74,
#           'NUM+NSUFF-MD': 66,
#           'NOUN+NSUFF-MS': 64,
#           'DET+NOUN+NSUFF-MD': 62,
#           'NUM+NSUFF-MP': 50,
#           'DET+ADJ+NSUFF+NSUFF-FD': 42,
#           'DET+NOUN+NSUFF+NSUFF-FP': 35,
#           '10': 30,
#           'ADJ+NSUFF-MD': 29,
#           'DET+ADJ+NSUFF-MD': 28,
#           'NUM+NSUFF-MS': 27,
#           'NOUN-MD': 26,
#           'NOUN+NSUFF+NSUFF-MP': 17,
#           'DET+NUM+NSUFF-FS': 16,
#           'DET+NOUN+NSUFF-MS': 13,
#           'DET+NUM+NSUFF-MP': 12,
#           'NOUN+NSUFF+NSUFF-FS': 12,
#           '5': 11,
#           'DET+NUM+NSUFF-MD': 9,
#           'NUM-MD': 7,
#           'NOUN+NSUFF+NSUFF-MD': 5,
#           'NUM+NSUFF+NSUFF-MD': 5,
#           'DET+NUM-MP': 5,
#           'DET+ADJ+NSUFF-MS': 4,
#           'DET+NUM-MS': 4,
#           'DET+NOUN+NSUFF+NSUFF-FS': 4,
#           '2': 4,
#           'NUM+NSUFF-FP': 3,
#           'DET+NUM+NSUFF-FP': 3,
#           '4': 3,
#           '7': 3,
#           '03': 2,
#           '3': 2,
#           'DET+NUM+NSUFF-MS': 2,
#           'NUM-FP': 2,
#           'DET+NOUN+NSUFF+NSUFF-MP': 1,
#           '1': 1,
#           '09': 1,
#           'ADJ+NSUFF-MS': 1,
#           '05': 1,
#           'DET+ADJ-FP': 1,
#           'DET+ADJ+NSUFF+NSUFF-FP': 1,
#           '90': 1,
#           'NUM+NSUFF-FD': 1,
#           '6': 1,
#           '80645': 1,
#           '100': 1,
#           '1437': 1}))

# %% [markdown]
# ## NER

# %%
ner_tagger = FarasaNamedEntityRecognizer(interactive=True)
# Out:
# [2025-09-01 09:49:51,660 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
ner_tagger.recognize(human_texts[0])
# Out:
# "هنا/O الكثير/O من/O منيف/B-PERS ،/O والكثير/O من/O شرق/O المتوسط/O أيضا/O ./O الأم/O هنا/O متعب/B-PERS الهذال/O في/O مدن/O الملح/O ،/O أما/O أنيسة/O ورجب/O وحامد/O فهم/O الإنسان/O بكل/O تقلباته/O ./O لم/O أحب/O شخصية/O أنيسة/O ،/O أزعجتني/O حقيقة/O ./O الرواية/O على/O أنها/O رائعة/O ،/O وعلى/O أنها/O ذكرتني/O بالأشجار/O واغتيال/O مرزوق/B-PERS وجوها/O العام/O ،/O إلا/O أنني/O توقعتها/O بشكل/O مختلف/O ./O توقعت/O السجون/O أرذل/O وأقذر/O وأقسى/O على/O الإنسان/O من/O هذا/O ،/O ولا/O أقصد/O الأوصاف/O الحسية/O هنا/O ./O لعلي/O أرى/O ماتوقعت/O في/O '/O الآن/O هنا/O ./O ./O '/O ./O شرق/B-LOC المتوسط/I-LOC -/O عبدالرحمن/B-PERS منيف/I-PERS ?/O ?/O ?/O ./O سوف/O تنام/O طويلا/O ،/O الموت/O والنوم/O متشابهان/O ./O لا/O فرق/O بينهما/O إلا/O ان/O الأول/O طويل/O والآخر/O قصير/O ،/O ألا/O تنهض/O لنعيش/O فترة/O أطول/O ؟/O ص/O ?/O ?/O ./O السجن/O والمرأة/O لا/O يجتمعان/O ،/O وبداية/O انهيار/O السجين/O ان/O يسيطر/O عليه/O شبح/O امرأة/O ./O كفوا/O عن/O هذا/O المرض/O أيها/O الثيران/O ،/O اخصوا/O أنفسكم/O لينتهي/O عذابكم/O !/O ص/O ?/O ?/O ./O ./O ./O ./O وانا/O من/O الذي/O ينتظرني/O ؟/O ص/O ?/O ?/O ./O ./O ./O ./O وفي/O تلك/O الدقائق/O ،/O التي/O لم/O تكن/O تزيد/O على/O العشر/O أتزود/O بالقوة/O ،/O بالجنون/O ،/O بالمحبة/O ،/O كنت/O أتزود/O منها/O لفترة/O طويلة/O تكفيني/O أسابيع/O ،/O حتى/O عندما/O يمنعون/O الزيارة/O ./O ص/O ?/O ?/O ./O وصمتت/O تاركة/O لدمعة/O كبيرة/O ان/O تسقط/O دون/O ان/O توقفها/O او/O تمسحها/O كما/O تعودت/
/O ولا/O أبكي/O أمامه/O ./O كانت/O تقول/O :/O '/O البكاء/O يهد/O اكبر/O الرجال/O ،/O وأقسى/O ضربة/O توجه/O لرجل/O ان/O يرى/O أمه/O او/O أخته/O تبكي/O امامه/O '/O ./O لن/O أبكي/O الآن/O ./O لن/O أبكي/O ./O سأدفن/O وجهي/O في/O صدره/O وأقبله/O ،/O وبعد/O أن/O يغيب/O سأبكي/O ،/O سأبكي/O وحدي/O ،/O لن/O أترك/O له/O في/O غربته/O ذكرى/O دموعي/O ،/O وكأنها/O نجوم/O سوداء/O تتساقط/O عليه/O لتضغط/O على/O قلبه/O ./O سأضحك/O ،/O لكن/O فكي/O لا/O يطاوعني/O ،/O أحسهما/O ثقيلين/O متصلبين/O ،/O سأبتسم/O ،/O الانسان/O يستطيع/O ان/O يبتسم/O ،/O والابتسامة/O ارادة/O حتى/O لو/O كانت/O حزينة/O !/O ...

# %%
annotated_human_texts = []
annotated_ai_texts = []

# %%
for human_text, ai_text in tqdm(zip(human_texts, ai_texts),total=len(human_texts)):
    annotated_human_texts.extend(get_text_annotation(ner_tagger.recognize, human_text))
    annotated_ai_texts.extend(get_text_annotation(ner_tagger.recognize, ai_text))
# Out:
#   0%|          | 0/3318 [00:00<?, ?it/s]

# %%
human_tag_counts = Counter([tag for word, tag in annotated_human_texts])
ai_tag_counts = Counter([tag for word, tag in annotated_ai_texts])
human_tag_counts, ai_tag_counts
# Out:
# (Counter({'O': 3271872,
#           'B-PERS': 32309,
#           'I-PERS': 19899,
#           'B-LOC': 15986,
#           'B-ORG': 3974,
#           'I-ORG': 2016,
#           '': 1916,
#           'I-LOC': 1181,
#           'I-PER': 58,
#           '10': 57,
#           'B-PER': 51,
#           '5': 43,
#           '.': 37,
#           '2': 8,
#           '4': 7,
#           '3': 6,
#           '7': 5,
#           '0': 5,
#           '6': 4,
#           '1': 4,
#           '04': 3,
#           '01': 3,
#           '12': 3,
#           '06': 3,
#           '90': 3,
#           '02': 2,
#           '08': 2,
#           '05': 2,
#           '553': 1,
#           '265': 1,
#           '186': 1,
#           '142': 1,
#           '228': 1,
#           '23': 1,
#           '11': 1,
#           '4552': 1,
#           '26': 1,
#           '72129': 1,
#           '03': 1,
#           '09': 1,
#           '170': 1,
#           '2003': 1,
#           '24': 1,
#           '72': 1,
#           '54': 1,
#           '230': 1,
#           '185': 1,
#           '951': 1,
#           '231': 1,
#           '80645': 1,
#           'UN_TAGGED': 1,
#           '20': 1}),
#  Counter({'O': 1169350,
#           'B-PERS': 11994,
#           'I-PERS': 7608,
#           'B-LOC': 5841,
#           'B-ORG': 1306,
#           'I-ORG': 676,
#           'I-LOC': 496,
#           '': 377,
#           'B-PER': 63,
#           'I-PER': 33,
#           '10': 30,
#           '5': 11,
#           '2': 4,
#           '4': 3,
#           '7': 3,
#           '03': 2,
#           '3': 2,
#           '1': 1,
#           '09': 1,
#           '05': 1,
#           '90': 1,
#           '6': 1,
#           '80645': 1,
#           '100': 1,
#           '1437': 1}))

# %% [markdown]
# ## Segmentation

# %%
segmenter = FarasaSegmenter(interactive=True)
